# %%
import spacy
import os
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# File Collection

# %%
collPath = 'text-files'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# Out:
# jacobs-ladder-script
# 201710
# shinning-dialogue
# 501933
# game-dialogue
# 66380

# %% [markdown]
# Collection of Words

# %%
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# jacobs-ladder-script
# " ----> PUNCT ::::: "
# JACOB ----> PROPN ::::: JACOB
# 'S ----> PROPN ::::: 'S
# LADDER ----> NOUN ::::: ladder
# " ----> PUNCT ::::: "
#
#
#  ----> SPACE :::::
#
#
# by ----> ADP ::::: by
#
#
#  ----> SPACE :::::
#
#
# Bruce ----> PROPN ::::: Bruce
# Joel ----> PROPN ::::: Joel
# Rubin ----> PROPN ::::: Rubin
#
#
#
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
#
#
#
# EXT ----> PROPN ::::: EXT
# . ----> PUNCT ::::: .
#   ----> SPACE :::::
# VIETNAM ----> PROPN ::::: VIETNAM
# - ----> PUNCT ::::: -
# DUSK ----> PROPN ::::: DUSK
#
#
#  ----> SPACE :::::
#
#
# A ----> DET ::::: a
# swarm ----> NOUN ::::: swarm
# of ----> ADP ::::: of
# helicopters ----> NOUN ::::: helicopter
# swoops ----> VERB ::::: swoop
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# a ----> DET ::::: a
# yellow ----> ADJ ::::: yellow
# sky ----> NOUN ::::: sky
# and ----> CCONJ ::::: and
# deposits ----> NOUN ::::: deposit
# an ----> DET ::::: an
# army ----> NOUN ::::: army
#
#  ----> SPACE :::::
#
# of ----> ADP ::::: of
# men ----> NOUN ::::: man
# over ----> ADP ::::: over
# a ----> DET ::::: a
# Vietnamese ----> ADJ ::::: vietnamese
# hillside ----> NOUN ::::: hillside
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# SOLDIERS ----> NOUN ::::: soldier
# scramble ----> VERB ::::: scramble
# over ----> ADP ::::: over
# the ----> DET ::::: the
# terraced ----> VERB ::::: terrace
# rice ----> NOUN ::::: rice
# paddies ----> NOUN ::::: paddy
# for ----> ADP ::::: for
# the ----> DET ::::: the
# protection ----> NOUN ::::: protection
#
#  ----> SPACE :::::
#
# of ----> ADP ::::: of
# the ----> DET ::::: the
# jungle ----> NOUN ::::: jungle
# . ----> PUNCT ::::: .
# Falling ----> VERB ::::: fall
# into ----> ADP ::::: into
# coulmns ----> NOUN ::::: coulmn
# , ----> PUNCT ::::: ,
# like ----> ADP ::::: like
# strands ----> NOUN ::::: strand
# of ----> ADP ::::: of
# soldier ----> NOUN ::::: soldier
# ants ----> NOUN ::::: ant
# , ----> PUNCT ::::: ,
#
#  ----> SPACE :::::
#
# seventy ----> NUM ::::: seventy
# - ----> PUNCT ::::: -
# five ----> NUM ::::: five
# men ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# at ----> ADP ::::: at
# combat ----> NOUN ::::: combat
# readiness ----> NOUN ::::: readiness
# , ----> PUNCT ::::: ,
# assemble ----> VERB ::::: assemble
# on ----> ADP ::::: on
# the ----> DET ::::: the
# edge ----> NOUN ::::: edge
# of ----> ADP ::::: of
# a ----> DET ::::: a
#
#  ----> SPACE :::::
#
# sweltering ----> NOUN ::::: sweltering
# wilderness ----> NOUN ::::: wilderness
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# dusk ----> NOUN ::::: dusk
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# mood ----> NOUN ::::: mood
# is ----> AUX ::::: be
# lazy ----> ADJ ::::: lazy
# , ----> PUNCT ::::: ,
# soporific ----> ADJ ::::: soporific
# . ----> PUNCT ::::: .
# Members ----> NOUN ::::: member
# of ----> ADP ::::: of
# one ----> NUM ::::: one
# platoon ----> NOUN ::::: platoon
# huddle ----> NOUN ::::: huddle
#
#  ----> SPACE :::::
#
# close ----> ADV ::::: close
# to ----> ADP ::::: to
# the ----> DET ::::: the
# ground ----> NOUN ::::: ground
# smoking ----> VERB ::::: smoke
# a ----> DET ::::: a
# joint ----> NOUN ::::: joint
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JERRY ----> PROPN ::::: JERRY
#
# 		 ----> SPACE :::::
#
# Strong ----> PROPN ::::: Strong
# stuff ----> NOUN ::::: stuff
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# to ----> ADP ::::: to
# JACOB ----> PROPN ::::: JACOB
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# soldier ----> NOUN ::::: soldier
#
# 			 ----> SPACE :::::
#
# squatting ----> VERB ::::: squat
# several ----> ADJ ::::: several
# yards ----> NOUN ::::: yard
#
# 			 ----> SPACE :::::
#
# away ----> ADV ::::: away
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# Professor ----> PROPN ::::: Professor
# , ----> PUNCT ::::: ,
# how ----> SCONJ ::::: how
# many ----> ADJ ::::: many
# times ----> NOUN ::::: time
# can ----> AUX ::::: can
#
# 		 ----> SPACE :::::
#
# you ----> PRON ::::: you
# shit ----> VERB ::::: shit
# in ----> ADP ::::: in
# an ----> DET ::::: an
# hour ----> NOUN ::::: hour
# ? ----> PUNCT ::::: ?
#
#
# 				 ----> SPACE :::::
#
#
# GEORGE ----> PROPN ::::: GEORGE
#
# 		 ----> SPACE :::::
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# bug ----> VERB ::::: bug
# ' ----> PUNCT ::::: '
# i ----> PRON ::::: I
# m. ----> NOUN ::::: m.
#
#
# 				 ----> SPACE :::::
#
#
# DOUG ----> PROPN ::::: DOUG
#
# 		 ----> SPACE :::::
#
# Where ----> SCONJ ::::: where
# are ----> AUX ::::: be
# those ----> DET ::::: those
# gooks ----> NOUN ::::: gook
# already ----> ADV ::::: already
# ? ----> PUNCT ::::: ?
#
#
# 				 ----> SPACE :::::
#
#
# FRANK ----> PROPN ::::: FRANK
#
# 		 ----> SPACE :::::
#
# Some ----> DET ::::: some
# offensive ----> NOUN ::::: offensive
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# even ----> ADV ::::: even
# think ----> VERB ::::: think
#
# 		 ----> SPACE :::::
#
# they ----> PRON ::::: they
# 're ----> AUX ::::: be
# out ----> ADV ::::: out
# there ----> ADV ::::: there
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# Jesus ----> PROPN ::::: Jesus
# , ----> PUNCT ::::: ,
# this ----> DET ::::: this
# grass ----> NOUN ::::: grass
# is ----> AUX ::::: be
# something ----> PRON ::::: something
# else ----> ADV ::::: else
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# SINGER ----> NOUN ::::: singer
# returns ----> VERB ::::: return
# to ----> ADP ::::: to
# the ----> DET ::::: the
# group ----> NOUN ::::: group
# , ----> PUNCT ::::: ,
# pulling ----> VERB ::::: pull
# up ----> ADP ::::: up
# his ----> PRON ::::: his
# pants ----> NOUN ::::: pant
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 		 ----> SPACE :::::
#
# Why ----> SCONJ ::::: why
# even ----> ADV ::::: even
# bother ----> VERB ::::: bother
# to ----> PART ::::: to
# pull ----> VERB ::::: pull
# 'em ----> PRON ::::: them
# up ----> ADP ::::: up
# ? ----> PUNCT ::::: ?
#
#
# 				 ----> SPACE :::::
#
#
# FRANK ----> PROPN ::::: FRANK
#
# 		 ----> SPACE :::::
#
# You ----> PRON ::::: you
# jackin ----> VERB ::::: jackin
# ' ----> PUNCT ::::: '
# off ----> ADV ::::: off
# out ----> ADV ::::: out
# there ----> ADV ::::: there
# again ----> ADV ::::: again
# , ----> PUNCT ::::: ,
# huh ----> INTJ ::::: huh
#
# 		 ----> SPACE :::::
#
# Jake ----> PROPN ::::: Jake
# ? ----> PUNCT ::::: ?
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# get ----> VERB ::::: get
# off ----> ADP ::::: off
# his ----> PRON ::::: his
# back ----> NOUN ::::: back
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 		 ----> SPACE :::::
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# called ----> VERB ::::: call
# philosophizing ----> NOUN ::::: philosophizing
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
#
# 		 ----> SPACE :::::
#
# Professor ----> PROPN ::::: Professor
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# gives ----> VERB ::::: give
# them ----> PRON ::::: they
# the ----> DET ::::: the
# finger ----> NOUN ::::: finger
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 		 ----> SPACE :::::
#
# Up ----> ADP ::::: up
# yours ----> PRON ::::: yours
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# adolescent ----> ADJ ::::: adolescent
# scum ----> NOUN ::::: scum
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Laughter ----> PROPN ::::: Laughter
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# SERGEANT ----> PROPN ::::: SERGEANT
# ( ----> PUNCT ::::: (
# V.O. ----> PROPN ::::: V.O.
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Mount ----> PROPN ::::: Mount
# your ----> PRON ::::: your
# bayonets ----> NOUN ::::: bayonet
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# FRANK ----> PROPN ::::: FRANK
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# frightened ----> ADJ ::::: frightened
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Oh ----> INTJ ::::: oh
# shit ----> INTJ ::::: shit
# ! ----> PUNCT ::::: !
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# Goddam ----> PROPN ::::: Goddam
# ! ----> PUNCT ::::: !
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 		 ----> SPACE :::::
#
# Gimme ----> PROPN ::::: Gimme
# that ----> PRON ::::: that
# joint ----> VERB ::::: joint
# ! ----> PUNCT ::::: !
#
#
# 				 ----> SPACE :::::
#
#
# JERRY ----> PROPN ::::: JERRY
#
# 		 ----> SPACE :::::
#
# Hey ----> PROPN ::::: Hey
# , ----> PUNCT ::::: ,
# something ----> PRON ::::: something
# 's ----> AUX ::::: be
# wrong ----> ADJ ::::: wrong
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# GEORGE ----> PROPN ::::: GEORGE
#
# 		 ----> SPACE :::::
#
# What ----> PRON ::::: what
# is ----> AUX ::::: be
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
# 				 ----> SPACE :::::
#
#
# JERRY ----> PROPN ::::: JERRY
#
# 		 ----> SPACE :::::
#
# My ----> PRON ::::: my
# head ----> NOUN ::::: head
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# GEORGE ----> PROPN ::::: GEORGE
#
# 		 ----> SPACE :::::
#
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# nerves ----> NOUN ::::: nerve
# . ----> PUNCT ::::: .
# Take ----> VERB ::::: take
# another ----> DET ::::: another
# toke ----> NOUN ::::: toke
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# GEORGE ----> PROPN ::::: GEORGE
# reaches ----> VERB ::::: reach
# out ----> ADP ::::: out
# , ----> PUNCT ::::: ,
# extending ----> VERB ::::: extend
# a ----> DET ::::: a
# joint ----> NOUN ::::: joint
# . ----> PUNCT ::::: .
# Suddenly ----> ADV ::::: suddenly
# he ----> PRON ::::: he
# gasps ----> VERB ::::: gasp
# and ----> CCONJ ::::: and
# falls ----> VERB ::::: fall
# to ----> ADP ::::: to
#
#  ----> SPACE :::::
#
# the ----> DET ::::: the
# ground ----> NOUN ::::: ground
# , ----> PUNCT ::::: ,
# his ----> PRON ::::: his
# body ----> NOUN ::::: body
# convulsing ----> VERB ::::: convulse
# uncontrollably ----> ADV ::::: uncontrollably
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# others ----> NOUN ::::: other
# stand ----> VERB ::::: stand
# back ----> ADV ::::: back
# , ----> PUNCT ::::: ,
#
#  ----> SPACE :::::
#
# startled ----> VERB ::::: startle
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
# grabs ----> VERB ::::: grab
# him ----> PRON ::::: he
# and ----> CCONJ ::::: and
# shoves ----> VERB ::::: shove
# a ----> DET ::::: a
# rifle ----> NOUN ::::: rifle
# barrel ----> NOUN ::::: barrel
# between ----> ADP ::::: between
# his ----> PRON ::::: his
#
#  ----> SPACE :::::
#
# chattering ----> VERB ::::: chatter
# teeth ----> NOUN ::::: tooth
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 		 ----> SPACE :::::
#
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# Before ----> SCONJ ::::: before
# anyone ----> PRON ::::: anyone
# can ----> AUX ::::: can
# answer ----> VERB ::::: answer
# JERRY ----> PROPN ::::: JERRY
# grabs ----> VERB ::::: grab
# his ----> PRON ::::: his
# head ----> NOUN ::::: head
# , ----> PUNCT ::::: ,
# screaming ----> VERB ::::: scream
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# turns ----> VERB ::::: turn
#
#  ----> SPACE :::::
#
# frantically ----> ADV ::::: frantically
# in ----> ADP ::::: in
# all ----> DET ::::: all
# directions ----> NOUN ::::: direction
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JERRY ----> PROPN ::::: JERRY
#
# 		 ----> SPACE :::::
#
# Help ----> VERB ::::: help
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
# Help ----> VERB ::::: help
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# What ----> PRON ::::: what
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# ... ----> PUNCT ::::: ...
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# In ----> ADP ::::: in
# seconds ----> NOUN ::::: second
# JERRY ----> PROPN ::::: JERRY
# is ----> AUX ::::: be
# spinning ----> VERB ::::: spin
# wildly ----> ADV ::::: wildly
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# control ----> NOUN ::::: control
# , ----> PUNCT ::::: ,
# his ----> PRON ::::: his
# head ----> NOUN ::::: head
# shaking ----> VERB ::::: shake
#
#  ----> SPACE :::::
#
# into ----> ADP ::::: into
# a ----> DET ::::: a
# terrific ----> ADJ ::::: terrific
# blur ----> NOUN ::::: blur
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# crashes ----> VERB ::::: crash
# into ----> ADP ::::: into
# FRANK ----> PROPN ::::: FRANK
# with ----> ADP ::::: with
# the ----> DET ::::: the
# force ----> NOUN ::::: force
# of ----> ADP ::::: of
# a ----> DET ::::: a
# truck ----> NOUN ::::: truck
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# FRANK ----> PROPN ::::: FRANK
# slams ----> VERB ::::: slam
# into ----> ADP ::::: into
# the ----> DET ::::: the
# ground ----> NOUN ::::: ground
# as ----> SCONJ ::::: as
# all ----> DET ::::: all
# the ----> DET ::::: the
# air ----> NOUN ::::: air
# rushes ----> VERB ::::: rush
# from ----> ADP ::::: from
# his ----> PRON ::::: his
# lungs ----> NOUN ::::: lung
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
#
#  ----> SPACE :::::
#
# begins ----> VERB ::::: begin
# gasping ----> VERB ::::: gasp
# and ----> CCONJ ::::: and
# hyperventilating ----> NOUN ::::: hyperventilating
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# grow ----> VERB ::::: grow
# wide ----> ADJ ::::: wide
# and ----> CCONJ ::::: and
# frenzied ----> ADJ ::::: frenzied
# as ----> SCONJ ::::: as
#
#  ----> SPACE :::::
#
# he ----> PRON ::::: he
# gulps ----> VERB ::::: gulp
# for ----> ADP ::::: for
# air ----> NOUN ::::: air
# . ----> PUNCT ::::: .
# Fear ----> NOUN ::::: fear
# and ----> CCONJ ::::: and
# confusion ----> NOUN ::::: confusion
# sweep ----> NOUN ::::: sweep
# across ----> ADP ::::: across
# his ----> PRON ::::: his
# face ----> NOUN ::::: face
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# MEN ----> PROPN ::::: MEN
#
#  ----> SPACE :::::
#
# watch ----> PROPN ::::: watch
# , ----> PUNCT ::::: ,
# horrified ----> VERB ::::: horrify
# , ----> PUNCT ::::: ,
# as ----> SCONJ ::::: as
# FRANK ----> PROPN ::::: FRANK
# 's ----> PART ::::: 's
# terror ----> NOUN ::::: terror
# escalates ----> VERB ::::: escalate
# beyond ----> ADP ::::: beyond
# reason ----> NOUN ::::: reason
# into ----> ADP ::::: into
# all- ----> NOUN ::::: all-
#
#  ----> SPACE :::::
#
# out ----> ADP ::::: out
# panic ----> NOUN ::::: panic
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Suddenly ----> ADV ::::: suddenly
# FRANK ----> PROPN ::::: FRANK
# begins ----> VERB ::::: begin
# howling ----> VERB ::::: howl
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# lunges ----> VERB ::::: lunge
# for ----> ADP ::::: for
# his ----> PRON ::::: his
# bayonet ----> NOUN ::::: bayonet
# and ----> CCONJ ::::: and
# , ----> PUNCT ::::: ,
# without ----> ADP ::::: without
#
#  ----> SPACE :::::
#
# warning ----> NOUN ::::: warning
# , ----> PUNCT ::::: ,
# attacks ----> VERB ::::: attack
# the ----> DET ::::: the
# MEN ----> NOUN ::::: men
# around ----> ADP ::::: around
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# God ----> PROPN ::::: God
# Almighty ----> PROPN ::::: Almighty
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
# spins ----> VERB ::::: spin
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# way ----> NOUN ::::: way
# as ----> SCONJ ::::: as
# FRANK ----> PROPN ::::: FRANK
# 's ----> PART ::::: 's
# bayonet ----> NOUN ::::: bayonet
# impales ----> VERB ::::: impale
# the ----> DET ::::: the
# ground ----> NOUN ::::: ground
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
#
#  ----> SPACE :::::
#
# jumps ----> VERB ::::: jump
# on ----> ADP ::::: on
# top ----> NOUN ::::: top
# of ----> ADP ::::: of
# FRANK ----> PROPN ::::: FRANK
# and ----> CCONJ ::::: and
# wrestles ----> VERB ::::: wrestle
# him ----> PRON ::::: he
# into ----> ADP ::::: into
# the ----> DET ::::: the
# tall ----> ADJ ::::: tall
# grass ----> NOUN ::::: grass
# . ----> PUNCT ::::: .
# PAUL ----> PROPN ::::: PAUL
# rushes ----> VERB ::::: rush
#
#  ----> SPACE :::::
#
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# assistance ----> NOUN ::::: assistance
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# stares ----> VERB ::::: star
# at ----> ADP ::::: at
# FRANK ----> PROPN ::::: FRANK
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# as ----> ADP ::::: as
# FRANK ----> PROPN ::::: FRANK
# struggles ----> NOUN ::::: struggle
# beneath ----> ADP ::::: beneath
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# face ----> NOUN ::::: face
# of ----> ADP ::::: of
# a ----> DET ::::: a
# madman ----> NOUN ::::: madman
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# Good ----> PROPN ::::: Good
# God ----> PROPN ::::: God
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# happening ----> VERB ::::: happen
# ? ----> PUNCT ::::: ?
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# sudden ----> ADJ ::::: sudden
# chaos ----> NOUN ::::: chaos
# is ----> AUX ::::: be
# intensified ----> VERB ::::: intensify
# by ----> ADP ::::: by
# the ----> DET ::::: the
# sound ----> NOUN ::::: sound
# of ----> ADP ::::: of
# fighting ----> VERB ::::: fight
# erupting ----> NOUN ::::: erupting
#
#  ----> SPACE :::::
#
# behind ----> ADP ::::: behind
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
# Guns ----> NOUN ::::: gun
# crackle ----> VERB ::::: crackle
# and ----> CCONJ ::::: and
# bursts ----> NOUN ::::: burst
# of ----> ADP ::::: of
# light ----> NOUN ::::: light
# penetrate ----> VERB ::::: penetrate
# the ----> DET ::::: the
# darkening ----> NOUN ::::: darkening
#
#  ----> SPACE :::::
#
# sky ----> NOUN ::::: sky
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
#
# 		 ----> SPACE :::::
#
# Behind ----> ADP ::::: behind
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# Look ----> VERB ::::: look
# out ----> ADP ::::: out
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# MEN ----> PROPN ::::: MEN
# spin ----> VERB ::::: spin
# around ----> ADP ::::: around
# . ----> PUNCT ::::: .
# PAUL ----> PROPN ::::: PAUL
# panics ----> VERB ::::: panic
# and ----> CCONJ ::::: and
# jumps ----> VERB ::::: jump
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# feet ----> NOUN ::::: foot
# , ----> PUNCT ::::: ,
# leaving ----> VERB ::::: leave
# JACOB ----> PROPN ::::: JACOB
#
#  ----> SPACE :::::
#
# alone ----> ADV ::::: alone
# with ----> ADP ::::: with
# FRANK ----> PROPN ::::: FRANK
# . ----> PUNCT ::::: .
# FRANK ----> PROPN ::::: FRANK
# 's ----> PART ::::: 's
# eyes ----> NOUN ::::: eye
# burn ----> VERB ::::: burn
# with ----> ADP ::::: with
# demonic ----> ADJ ::::: demonic
# force ----> NOUN ::::: force
# as ----> SCONJ ::::: as
# he ----> PRON ::::: he
# gathers ----> VERB ::::: gather
#
#  ----> SPACE :::::
#
# his ----> PRON ::::: his
# strength ----> NOUN ::::: strength
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 		 ----> SPACE :::::
#
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# leave ----> VERB ::::: leave
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Dark ----> PROPN ::::: Dark
# figures ----> NOUN ::::: figure
# , ----> PUNCT ::::: ,
# silhouetted ----> VERB ::::: silhouette
# by ----> ADP ::::: by
# the ----> DET ::::: the
# setting ----> VERB ::::: set
# sun ----> NOUN ::::: sun
# , ----> PUNCT ::::: ,
# are ----> AUX ::::: be
# storming ----> VERB ::::: storm
# at ----> ADP ::::: at
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# SOLDIERS ----> NOUN ::::: soldier
# squint ----> VERB ::::: squint
# to ----> PART ::::: to
# see ----> VERB ::::: see
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# a ----> DET ::::: a
# horrifying ----> ADJ ::::: horrifying
# vision ----> NOUN ::::: vision
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# PAUL ----> PROPN ::::: PAUL
#
# 		 ----> SPACE :::::
#
# They ----> PRON ::::: they
# 're ----> AUX ::::: be
# coming ----> VERB ::::: come
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# Gunfire ----> PROPN ::::: Gunfire
# explodes ----> VERB ::::: explode
# on ----> ADP ::::: on
# all ----> DET ::::: all
# sides ----> NOUN ::::: side
# . ----> PUNCT ::::: .
# Suddenly ----> ADV ::::: suddenly
# PAUL ----> PROPN ::::: PAUL
# flips ----> VERB ::::: flip
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# begins ----> VERB ::::: begin
#
#  ----> SPACE :::::
#
# screaming ----> VERB ::::: scream
# uncontrollably ----> ADV ::::: uncontrollably
# , ----> PUNCT ::::: ,
# ripping ----> VERB ::::: rip
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# clothes ----> NOUN ::::: clothe
# and ----> CCONJ ::::: and
# skin ----> NOUN ::::: skin
# . ----> PUNCT ::::: .
# FRANK ----> PROPN ::::: FRANK
# is ----> AUX ::::: be
#
#  ----> SPACE :::::
#
# struggling ----> VERB ::::: struggle
# like ----> ADP ::::: like
# four ----> NUM ::::: four
# men ----> NOUN ::::: man
# and ----> CCONJ ::::: and
# JACOB ----> PROPN ::::: JACOB
# is ----> AUX ::::: be
# weakening ----> VERB ::::: weaken
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# effort ----> NOUN ::::: effort
# to ----> PART ::::: to
#
#  ----> SPACE :::::
#
# restrain ----> VERB ::::: restrain
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# Bayonets ----> NOUN ::::: bayonet
# glimmer ----> ADJ ::::: glimmer
# in ----> ADP ::::: in
# the ----> DET ::::: the
# exchange ----> NOUN ::::: exchange
# of ----> ADP ::::: of
# fire ----> NOUN ::::: fire
# . ----> PUNCT ::::: .
# Bodies ----> NOUN ::::: body
# fall ----> VERB ::::: fall
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# More ----> ADJ ::::: More
# bodies ----> NOUN ::::: body
# keep ----> VERB ::::: keep
# coming ----> VERB ::::: come
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# first ----> ADJ ::::: first
# wave ----> NOUN ::::: wave
# is ----> AUX ::::: be
# upon ----> SCONJ ::::: upon
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# ROD ----> PROPN ::::: ROD
# shoots ----> NOUN ::::: shoot
# into ----> ADP ::::: into
# the ----> DET ::::: the
# air ----> NOUN ::::: air
# . ----> PUNCT ::::: .
# Shadowy ----> ADJ ::::: shadowy
# forms ----> NOUN ::::: form
# hurl ----> VERB ::::: hurl
# forward ----> ADV ::::: forward
# screaming ----> VERB ::::: scream
# like ----> ADP ::::: like
#
#  ----> SPACE :::::
#
# banshees ----> NOUN ::::: banshee
# . ----> PUNCT ::::: .
# ROD ----> PROPN ::::: ROD
# , ----> PUNCT ::::: ,
# squinting ----> VERB ::::: squint
# , ----> PUNCT ::::: ,
# jabs ----> NOUN ::::: jab
# with ----> ADP ::::: with
# his ----> PRON ::::: his
# bayonet ----> NOUN ::::: bayonet
# , ----> PUNCT ::::: ,
# piercing ----> VERB ::::: pierce
# the ----> DET ::::: the
# belly ----> NOUN ::::: belly
# of ----> ADP ::::: of
#
#  ----> SPACE :::::
#
# his ----> PRON ::::: his
# attacker ----> NOUN ::::: attacker
# . ----> PUNCT ::::: .
# Agonizing ----> ADJ ::::: agonizing
# cries ----> NOUN ::::: cry
# accompany ----> VERB ::::: accompany
# his ----> PRON ::::: his
# fall ----> NOUN ::::: fall
# . ----> PUNCT ::::: .
# ROD ----> PROPN ::::: ROD
# yanks ----> VERB ::::: yank
# the ----> DET ::::: the
# bayonet ----> NOUN ::::: bayonet
#
#  ----> SPACE :::::
#
# out ----> ADP ::::: out
# and ----> CCONJ ::::: and
# stabs ----> VERB ::::: stab
# again ----> ADV ::::: again
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# In ----> ADP ::::: in
# the ----> DET ::::: the
# midst ----> NOUN ::::: midst
# of ----> ADP ::::: of
# this ----> DET ::::: this
# madness ----> NOUN ::::: madness
# FRANK ----> PROPN ::::: FRANK
# shoots ----> NOUN ::::: shoot
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# feet ----> NOUN ::::: foot
# and ----> CCONJ ::::: and
# slams ----> VERB ::::: slam
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# butt ----> NOUN ::::: butt
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# rifle ----> NOUN ::::: rifle
# into ----> ADP ::::: into
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
# back ----> NOUN ::::: back
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# cracking ----> NOUN ::::: cracking
# sound ----> NOUN ::::: sound
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
#
#  ----> SPACE :::::
#
# eyes ----> NOUN ::::: eye
# freeze ----> VERB ::::: freeze
# with ----> ADP ::::: with
# pain ----> NOUN ::::: pain
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# rush ----> NOUN ::::: rush
# for ----> ADP ::::: for
# his ----> PRON ::::: his
# spine ----> NOUN ::::: spine
# . ----> PUNCT ::::: .
# As ----> SCONJ ::::: as
# he ----> PRON ::::: he
# spins ----> VERB ::::: spin
# around ----> ADP ::::: around
#
#  ----> SPACE :::::
#
# one ----> NUM ::::: one
# of ----> ADP ::::: of
# the ----> DET ::::: the
# ATTACKERS ----> PROPN ::::: ATTACKERS
# jams ----> VERB ::::: jam
# all ----> DET ::::: all
# eight ----> NUM ::::: eight
# inches ----> NOUN ::::: inch
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# bayonet ----> NOUN ::::: bayonet
# blade ----> NOUN ::::: blade
# into ----> ADP ::::: into
#
#  ----> SPACE :::::
#
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
# stomach ----> NOUN ::::: stomach
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
# screams ----> VERB ::::: scream
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# a ----> DET ::::: a
# loud ----> ADJ ::::: loud
# and ----> CCONJ ::::: and
# piercing ----> VERB ::::: pierce
# wail ----> NOUN ::::: wail
# . ----> PUNCT ::::: .
#
#
#
#  ----> SPACE :::::
#
#
#
# CUT ----> PROPN ::::: CUT
# ON ----> ADP ::::: on
# THE ----> DET ::::: the
# SOUND ----> NOUN ::::: sound
# OF ----> ADP ::::: of
# THE ----> DET ::::: the
# SCREAM ----> NOUN ::::: scream
# to ----> ADP ::::: to
# a ----> DET ::::: a
# sudden ----> ADJ ::::: sudden
# rush ----> NOUN ::::: rush
# through ----> ADP ::::: through
# a ----> DET ::::: a
# long ----> ADJ ::::: long
# dark ----> ADJ ::::: dark
#
#  ----> SPACE :::::
#
# tunnel ----> NOUN ::::: tunnel
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# sense ----> NOUN ::::: sense
# of ----> ADP ::::: of
# enormous ----> ADJ ::::: enormous
# speed ----> NOUN ::::: speed
# accelerating ----> VERB ::::: accelerate
# toward ----> ADP ::::: toward
# a ----> DET ::::: a
#
#  ----> SPACE :::::
#
# brilliant ----> ADJ ::::: brilliant
# light ----> NOUN ::::: light
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# rush ----> NOUN ::::: rush
# suggests ----> VERB ::::: suggest
# a ----> DET ::::: a
# passage ----> NOUN ::::: passage
# between ----> ADP ::::: between
# life ----> NOUN ::::: life
# and ----> CCONJ ::::: and
# death ----> NOUN ::::: death
# , ----> PUNCT ::::: ,
#
#  ----> SPACE :::::
#
# but ----> CCONJ ::::: but
# as ----> SCONJ ::::: as
# the ----> DET ::::: the
# light ----> ADJ ::::: light
# bursts ----> NOUN ::::: burst
# upon ----> SCONJ ::::: upon
# us ----> PRON ::::: we
# we ----> PRON ::::: we
# realize ----> VERB ::::: realize
# that ----> SCONJ ::::: that
# we ----> PRON ::::: we
# are ----> AUX ::::: be
# passing ----> VERB ::::: pass
# through ----> ADP ::::: through
#
#  ----> SPACE :::::
#
# a ----> DET ::::: a
# SUBWAY ----> NOUN ::::: subway
# STATION ----> NOUN ::::: station
# far ----> ADV ::::: far
# below ----> ADP ::::: below
# the ----> DET ::::: the
# city ----> NOUN ::::: city
# of ----> ADP ::::: of
# NEW ----> PROPN ::::: NEW
# YORK ----> PROPN ::::: YORK
# . ----> PUNCT ::::: .
#
#
#
#  ----> SPACE :::::
#
#
#
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
#   ----> SPACE :::::
# SUBWAY ----> PROPN ::::: SUBWAY
# - ----> PUNCT ::::: -
# NIGHT ----> PROPN ::::: NIGHT
#
#
#  ----> SPACE :::::
#
#
# THE ----> DET ::::: the
# WHEELS ----> PROPN ::::: WHEELS
# OF ----> ADP ::::: of
# AN ----> PROPN ::::: AN
# EXPRESS ----> PROPN ::::: EXPRESS
# TRAIN ----> PROPN ::::: TRAIN
# screech ----> NOUN ::::: screech
# through ----> ADP ::::: through
# the ----> DET ::::: the
# station ----> NOUN ::::: station
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
#
#  ----> SPACE :::::
#
# SINGER ----> PROPN ::::: SINGER
# , ----> PUNCT ::::: ,
# sitting ----> VERB ::::: sit
# alone ----> ADV ::::: alone
# in ----> ADP ::::: in
# the ----> DET ::::: the
# last ----> ADJ ::::: last
# car ----> NOUN ::::: car
# , ----> PUNCT ::::: ,
# wakes ----> VERB ::::: wake
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# sounds ----> NOUN ::::: sound
# of ----> ADP ::::: of
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# scream ----> NOUN ::::: scream
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# grating ----> VERB ::::: grate
# wheels ----> NOUN ::::: wheel
# merge ----> VERB ::::: merge
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# dazed ----> VERB ::::: daze
# and ----> CCONJ ::::: and
# confused ----> ADJ ::::: confused
# , ----> PUNCT ::::: ,
# not ----> PART ::::: not
#
#  ----> SPACE :::::
#
# certain ----> ADJ ::::: certain
# where ----> SCONJ ::::: where
# he ----> PRON ::::: he
# is ----> AUX ::::: be
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# glances ----> VERB ::::: glance
# around ----> ADP ::::: around
# the ----> DET ::::: the
# empty ----> ADJ ::::: empty
# car ----> NOUN ::::: car
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# gravitate ----> VERB ::::: gravitate
# to ----> ADP ::::: to
# overhead ----> NOUN ::::: overhead
#
#  ----> SPACE :::::
#
# advertisements ----> NOUN ::::: advertisement
# for ----> ADP ::::: for
# hemorrhoid ----> ADJ ::::: hemorrhoid
# perparations ----> NOUN ::::: perparation
# and ----> CCONJ ::::: and
# savings ----> NOUN ::::: saving
# banks ----> NOUN ::::: bank
# . ----> PUNCT ::::: .
# Gradually ----> ADV ::::: gradually
#
#  ----> SPACE :::::
#
# his ----> PRON ::::: his
# confusion ----> NOUN ::::: confusion
# subsides ----> VERB ::::: subside
# . ----> PUNCT ::::: .
# Shifting ----> VERB ::::: shift
# uncomfortably ----> ADV ::::: uncomfortably
# he ----> PRON ::::: he
# pulls ----> VERB ::::: pull
# a ----> DET ::::: a
# thick ----> ADJ ::::: thick
# book ----> NOUN ::::: book
#
#  ----> SPACE :::::
#
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# back ----> NOUN ::::: back
# pocket ----> NOUN ::::: pocket
# , ----> PUNCT ::::: ,
# " ----> PUNCT ::::: "
# The ----> DET ::::: the
# Stranger ----> NOUN ::::: stranger
# " ----> PUNCT ::::: "
# by ----> ADP ::::: by
# Albert ----> PROPN ::::: Albert
# Camus ----> PROPN ::::: Camus
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# begins ----> VERB ::::: begin
#
#  ----> SPACE :::::
#
# reading ----> VERB ::::: read
# . ----> PUNCT ::::: .
# Another ----> DET ::::: another
# station ----> NOUN ::::: station
# blurs ----> VERB ::::: blur
# by ----> ADP ::::: by
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# is ----> AUX ::::: be
# a ----> DET ::::: a
# good ----> ADV ::::: good
# - ----> PUNCT ::::: -
# looking ----> VERB ::::: look
# man ----> NOUN ::::: man
# , ----> PUNCT ::::: ,
# of ----> ADP ::::: of
# obvious ----> ADJ ::::: obvious
# intelligence ----> NOUN ::::: intelligence
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# in ----> ADP ::::: in
# his ----> PRON ::::: his
# mid- ----> ADJ ::::: mid-
#
#  ----> SPACE :::::
#
# thirties ----> NOUN ::::: thirty
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# surprising ----> ADJ ::::: surprising
# that ----> SCONJ ::::: that
# he ----> PRON ::::: he
# is ----> AUX ::::: be
# wearing ----> VERB ::::: wear
# a ----> DET ::::: a
# mailman ----> NOUN ::::: mailman
# 's ----> PART ::::: 's
# uniform ----> NOUN ::::: uniform
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
#
#  ----> SPACE :::::
#
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# look ----> VERB ::::: look
# like ----> ADP ::::: like
# one ----> NUM ::::: one
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# subway ----> NOUN ::::: subway
# ride ----> NOUN ::::: ride
# seems ----> VERB ::::: seem
# to ----> PART ::::: to
# go ----> VERB ::::: go
# on ----> ADP ::::: on
# interminably ----> ADV ::::: interminably
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
# is ----> AUX ::::: be
# restless ----> ADJ ::::: restless
# and ----> CCONJ ::::: and
#
#  ----> SPACE :::::
#
# concerned ----> VERB ::::: concern
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# glances ----> VERB ::::: glance
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# watch ----> NOUN ::::: watch
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# 3:30 ----> NUM ::::: 3:30
# A.M. ----> PROPN ::::: A.M.
# Putting ----> VERB ::::: put
# his ----> PRON ::::: his
# book ----> NOUN ::::: book
# in ----> ADP ::::: in
#
#  ----> SPACE :::::
#
# his ----> PRON ::::: his
# back ----> NOUN ::::: back
# pocket ----> NOUN ::::: pocket
# , ----> PUNCT ::::: ,
# JACOB ----> PROPN ::::: JACOB
# stands ----> VERB ::::: stand
# up ----> ADP ::::: up
# and ----> CCONJ ::::: and
# makes ----> VERB ::::: make
# his ----> PRON ::::: his
# way ----> NOUN ::::: way
# through ----> ADP ::::: through
# the ----> DET ::::: the
# deserted ----> ADJ ::::: deserted
#
#  ----> SPACE :::::
#
# car ----> NOUN ::::: car
# . ----> PUNCT ::::: .
#
#
#
#  ----> SPACE :::::
#
#
#
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
#   ----> SPACE :::::
# SUBWAY ----> NOUN ::::: subway
# TRACKS ----> PROPN ::::: TRACKS
# - ----> PUNCT ::::: -
# NIGHT ----> PROPN ::::: NIGHT
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# enters ----> VERB ::::: enter
# the ----> DET ::::: the
# rumbling ----> VERB ::::: rumble
# passageway ----> NOUN ::::: passageway
# between ----> ADP ::::: between
# the ----> DET ::::: the
# cars ----> NOUN ::::: car
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# wheels ----> NOUN ::::: wheel
# spark ----> VERB ::::: spark
#
#  ----> SPACE :::::
#
# against ----> ADP ::::: against
# the ----> DET ::::: the
# rails ----> NOUN ::::: rail
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# dark ----> ADJ ::::: dark
# tunnel ----> NOUN ::::: tunnel
# walls ----> NOUN ::::: wall
# flash ----> VERB ::::: flash
# by ----> ADV ::::: by
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# pulls ----> VERB ::::: pull
# the ----> DET ::::: the
# handle ----> NOUN ::::: handle
#
#  ----> SPACE :::::
#
# on ----> ADP ::::: on
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# to ----> ADP ::::: to
# the ----> DET ::::: the
# next ----> ADJ ::::: next
# car ----> NOUN ::::: car
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# stuck ----> VERB ::::: stick
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# struggles ----> VERB ::::: struggle
# with ----> ADP ::::: with
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# LADY ----> NOUN ::::: lady
#
#  ----> SPACE :::::
#
# sitting ----> VERB ::::: sit
# alone ----> ADV ::::: alone
# inside ----> ADV ::::: inside
# turns ----> NOUN ::::: turn
# to ----> PART ::::: to
# look ----> VERB ::::: look
# at ----> ADP ::::: at
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# seems ----> VERB ::::: seem
# threatened ----> VERB ::::: threaten
# by ----> ADP ::::: by
# his ----> PRON ::::: his
#
#  ----> SPACE :::::
#
# effort ----> NOUN ::::: effort
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# motions ----> VERB ::::: motion
# for ----> SCONJ ::::: for
# her ----> PRON ::::: she
# to ----> PART ::::: to
# help ----> VERB ::::: help
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# turns ----> VERB ::::: turn
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# A ----> DET ::::: a
# look ----> NOUN ::::: look
# of ----> ADP ::::: of
# disgust ----> ADJ ::::: disgust
# crosses ----> NOUN ::::: cross
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
# face ----> NOUN ::::: face
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# kicks ----> VERB ::::: kick
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# slides ----> VERB ::::: slide
#
#  ----> SPACE :::::
#
# open ----> ADJ ::::: open
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# WOMAN ----> PROPN ::::: WOMAN
# seems ----> VERB ::::: seem
# frightened ----> ADJ ::::: frightened
# as ----> SCONJ ::::: as
# he ----> PRON ::::: he
# approaches ----> VERB ::::: approach
# her ----> PRON ::::: she
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 		 ----> SPACE :::::
#
# Excuse ----> PROPN ::::: Excuse
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# know ----> VERB ::::: know
# if ----> SCONJ ::::: if
# we ----> PRON ::::: we
# 've ----> AUX ::::: have
#
# 		 ----> SPACE :::::
#
# passed ----> VERB ::::: pass
# Nostrand ----> PROPN ::::: Nostrand
# Avenue ----> PROPN ::::: Avenue
# yet ----> ADV ::::: yet
# ? ----> PUNCT ::::: ?
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# she ----> PRON ::::: she
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# answer ----> VERB ::::: answer
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Excuse ----> VERB ::::: excuse
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# she ----> PRON ::::: she
# does ----> AUX ::::: do
# not ----> PART ::::: not
#
# 			 ----> SPACE :::::
#
# acknowledge ----> VERB ::::: acknowledge
# his ----> PRON ::::: his
#
# 			 ----> SPACE :::::
#
# existence ----> NOUN ::::: existence
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Look ----> VERB ::::: look
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# asking ----> VERB ::::: ask
# a ----> DET ::::: a
# simple ----> ADJ ::::: simple
# question ----> NOUN ::::: question
# . ----> PUNCT ::::: .
#
# 		 ----> SPACE :::::
#
# Have ----> AUX ::::: have
# we ----> PRON ::::: we
# hit ----> VERB ::::: hit
# Nostrand ----> PROPN ::::: Nostrand
# Avenue ----> PROPN ::::: Avenue
# ? ----> PUNCT ::::: ?
# I ----> PRON ::::: I
# fell ----> VERB ::::: fall
#
# 		 ----> SPACE :::::
#
# asleep ----> ADJ ::::: asleep
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# WOMAN ----> PROPN ::::: WOMAN
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# speaking ----> VERB ::::: speak
# with ----> ADP ::::: with
# a ----> DET ::::: a
# Puerto ----> PROPN ::::: Puerto
#
# 			 ----> SPACE :::::
#
# Rican ----> ADJ ::::: rican
# accent ----> NOUN ::::: accent
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# I ----> PRON ::::: I
# no ----> INTJ ::::: no
# from ----> ADP ::::: from
# around ----> ADV ::::: around
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 			 ----> SPACE :::::
#
# ( ----> PUNCT ::::: (
# glad ----> ADJ ::::: glad
# for ----> ADP ::::: for
# a ----> DET ::::: a
# response ----> NOUN ::::: response
# ) ----> PUNCT ::::: )
#
# 		 ----> SPACE :::::
#
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# and ----> CCONJ ::::: and
# everyone ----> PRON ::::: everyone
# else ----> ADV ::::: else
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# walks ----> VERB ::::: walk
# to ----> ADP ::::: to
# the ----> DET ::::: the
# other ----> ADJ ::::: other
# end ----> NOUN ::::: end
# of ----> ADP ::::: of
# the ----> DET ::::: the
# car ----> NOUN ::::: car
# and ----> CCONJ ::::: and
# sits ----> VERB ::::: sit
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# only ----> ADJ ::::: only
# other ----> ADJ ::::: other
#
#  ----> SPACE :::::
#
# passenger ----> NOUN ::::: passenger
# is ----> AUX ::::: be
# an ----> DET ::::: an
# OLD ----> ADJ ::::: old
# MAN ----> NOUN ::::: man
# lying ----> VERB ::::: lie
# asleep ----> ADJ ::::: asleep
# on ----> ADP ::::: on
# the ----> DET ::::: the
# fiberglass ----> NOUN ::::: fiberglass
# bench ----> NOUN ::::: bench
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Occasionally ----> ADV ::::: occasionally
# his ----> PRON ::::: his
# body ----> NOUN ::::: body
# shudders ----> VERB ::::: shudder
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# the ----> DET ::::: the
# only ----> ADJ ::::: only
# sign ----> NOUN ::::: sign
# of ----> ADP ::::: of
# life ----> NOUN ::::: life
# in ----> ADP ::::: in
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# train ----> NOUN ::::: train
# begins ----> VERB ::::: begin
# to ----> PART ::::: to
# slow ----> VERB ::::: slow
# down ----> ADP ::::: down
# . ----> PUNCT ::::: .
# JACOB ----> PROPN ::::: JACOB
# peers ----> VERB ::::: peer
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# the ----> DET ::::: the
# window ----> NOUN ::::: window
# . ----> PUNCT ::::: .
# Nostrand ----> PROPN ::::: Nostrand
#
#  ----> SPACE :::::
#
# Avenue ----> PROPN ::::: Avenue
# signs ----> NOUN ::::: sign
# appear ----> VERB ::::: appear
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# relieved ----> VERB ::::: relieve
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# gets ----> VERB ::::: get
# up ----> ADP ::::: up
# and ----> CCONJ ::::: and
# grabs ----> VERB ::::: grab
# hold ----> NOUN ::::: hold
# of ----> ADP ::::: of
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# overhead ----> ADJ ::::: overhead
# bar ----> NOUN ::::: bar
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# OLD ----> ADJ ::::: old
# MAN ----> PROPN ::::: MAN
# shudders ----> VERB ::::: shudder
# and ----> CCONJ ::::: and
# stretches ----> VERB ::::: stretch
# out ----> ADP ::::: out
# on ----> ADP ::::: on
# the ----> DET ::::: the
# seat ----> NOUN ::::: seat
# . ----> PUNCT ::::: .
# As ----> SCONJ ::::: as
# he ----> PRON ::::: he
# adjusts ----> VERB ::::: adjust
# his ----> PRON ::::: his
#
#  ----> SPACE :::::
#
# position ----> NOUN ::::: position
# , ----> PUNCT ::::: ,
# tugging ----> VERB ::::: tug
# at ----> ADP ::::: at
# his ----> PRON ::::: his
# coat ----> NOUN ::::: coat
# , ----> PUNCT ::::: ,
# JACOB ----> PROPN ::::: JACOB
# catches ----> VERB ::::: catch
# a ----> DET ::::: a
# brief ----> ADJ ::::: brief
# glimpse ----> NOUN ::::: glimpse
# of ----> ADP ::::: of
#
#  ----> SPACE :::::
#
# something ----> PRON ::::: something
# protruding ----> VERB ::::: protrude
# from ----> ADP ::::: from
# beneath ----> ADP ::::: beneath
# the ----> DET ::::: the
# coat ----> NOUN ::::: coat
# 's ----> PART ::::: 's
# hem ----> NOUN ::::: hem
# . ----> PUNCT ::::: .
# His ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# fixate ----> VERB ::::: fixate
# on ----> ADP ::::: on
#
#  ----> SPACE :::::
#
# the ----> DET ::::: the
# spot ----> NOUN ::::: spot
# , ----> PUNCT ::::: ,
# waiting ----> VERB ::::: wait
# for ----> ADP ::::: for
# another ----> DET ::::: another
# look ----> NOUN ::::: look
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# slight ----> ADJ ::::: slight
# movement ----> NOUN ::::: movement
# and ----> CCONJ ::::: and
# it ----> PRON ::::: it
#
#  ----> SPACE :::::
#
# appears ----> VERB ::::: appear
# - ----> PUNCT ::::: -
# a ----> DET ::::: a
# long ----> ADJ ::::: long
# , ----> PUNCT ::::: ,
# red ----> ADJ ::::: red
# , ----> PUNCT ::::: ,
# fleshy ----> ADJ ::::: fleshy
# protuberance ----> NOUN ::::: protuberance
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# sight ----> NOUN ::::: sight
# of ----> ADP ::::: of
# it ----> PRON ::::: it
# sends ----> VERB ::::: send
#
#  ----> SPACE :::::
#
# shivers ----> VERB ::::: shiver
# up ----> ADP ::::: up
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
# spine ----> NOUN ::::: spine
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# looks ----> VERB ::::: look
# strangely ----> ADV ::::: strangely
# like ----> ADP ::::: like
# a ----> DET ::::: a
# tail ----> NOUN ::::: tail
# . ----> PUNCT ::::: .
# Only ----> ADV ::::: only
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# stopping ----> NOUN ::::: stopping
# of ----> ADP ::::: of
# the ----> DET ::::: the
# train ----> NOUN ::::: train
# breaks ----> NOUN ::::: break
# JACOB ----> PROPN ::::: JACOB
# 's ----> PART ::::: 's
# stare ----> NOUN ::::: stare
# . ----> PUNCT ::::: .
#
#
#
#  ----> SPACE :::::
#
#
#
# INT ----> PROPN ::::: INT
# . ----> PUNCT ::::: .
#   ----> SPACE :::::
# SUBWAY ----> PROPN ::::: SUBWAY
# STATION ----> PROPN ::::: STATION
# - ----> PUNCT ::::: -
# NIGHT ----> PROPN ::::: NIGHT
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# is ----> AUX ::::: be
# the ----> DET ::::: the
# only ----> ADJ ::::: only
# passenger ----> NOUN ::::: passenger
# getting ----> VERB ::::: get
# off ----> ADP ::::: off
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# doors ----> NOUN ::::: door
# close ----> VERB ::::: close
# quickly ----> ADV ::::: quickly
# behind ----> ADP ::::: behind
#
#  ----> SPACE :::::
#
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# glances ----> VERB ::::: glance
# at ----> ADP ::::: at
# the ----> DET ::::: the
# LADY ----> NOUN ::::: lady
# sitting ----> VERB ::::: sit
# by ----> ADP ::::: by
# the ----> DET ::::: the
# window ----> NOUN ::::: window
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# is ----> VERB ::::: be
# a ----> DET ::::: a
# fearful ----> ADJ ::::: fearful
#
#  ----> SPACE :::::
#
# expression ----> NOUN ::::: expression
# on ----> ADP ::::: on
# her ----> PRON ::::: her
# face ----> NOUN ::::: face
# as ----> SCONJ ::::: as
# the ----> DET ::::: the
# train ----> NOUN ::::: train
# carries ----> VERB ::::: carry
# her ----> PRON ::::: she
# back ----> ADV ::::: back
# into ----> ADP ::::: into
# the ----> DET ::::: the
# dark ----> ADJ ::::: dark
#
#  ----> SPACE :::::
#
# tunnel ----> NOUN ::::: tunnel
# , ----> PUNCT ::::: ,
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# his ----> PRON ::::: his
# sight ----> NOUN ::::: sight
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
# reaches ----> VERB ::::: reach
# the ----> DET ::::: the
# exit ----> NOUN ::::: exit
# , ----> PUNCT ::::: ,
# a ----> DET ::::: a
# huge ----> ADJ ::::: huge
# metal ----> NOUN ::::: metal
# revolving ----> NOUN ::::: revolving
# door ----> NOUN ::::: door
# surrounded ----> VERB ::::: surround
# by ----> ADP ::::: by
# floor ----> NOUN ::::: floor
#
#  ----> SPACE :::::
#
# to ----> ADP ::::: to
# ceiling ----> NOUN ::::: ceiling
# gates ----> NOUN ::::: gate
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# is ----> AUX ::::: be
# about ----> ADJ ::::: about
# to ----> PART ::::: to
# push ----> VERB ::::: push
# when ----> SCONJ ::::: when
# he ----> PRON ::::: he
# notices ----> VERB ::::: notice
# a ----> DET ::::: a
# chain ----> NOUN ::::: chain
# locking ----> NOUN ::::: locking
#
#  ----> SPACE :::::
#
# it ----> PRON ::::: it
# shut ----> VERB ::::: shut
# . ----> PUNCT ::::: .
# He ----> PRON ::::: he
# stares ----> VERB ::::: star
# at ----> ADP ::::: at
# it ----> PRON ::::: it
# in ----> ADP ::::: in
# disbelief ----> NOUN ::::: disbelief
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 		 ----> SPACE :::::
#
# Goddam ----> PROPN ::::: Goddam
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# turns ----> VERB ::::: turn
# in ----> ADP ::::: in
# a ----> DET ::::: a
# huff ----> NOUN ::::: huff
# and ----> CCONJ ::::: and
# hikes ----> NOUN ::::: hike
# to ----> ADP ::::: to
# the ----> DET ::::: the
# other ----> ADJ ::::: other
# end ----> NOUN ::::: end
# of ----> ADP ::::: of
# the ----> DET ::::: the
# platform ----> NOUN ::::: platform
# . ----> PUNCT ::::: .
# As ----> SCONJ ::::: as
# he ----> PRON ::::: he
#
#  ----> SPACE :::::
#
# approaches ----> VERB ::::: approach
# the ----> DET ::::: the
# far ----> ADJ ::::: far
# exit ----> NOUN ::::: exit
# , ----> PUNCT ::::: ,
# his ----> PRON ::::: his
# eyes ----> NOUN ::::: eye
# widen ----> VERB ::::: widen
# . ----> PUNCT ::::: .
# The ----> DET ::::: the
# gate ----> NOUN ::::: gate
# there ----> PRON ::::: there
# is ----> VERB ::::: be
# also ----> ADV ::::: also
# locked ----> VERB ::::: lock
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# His ----> PRON ::::: his
# hands ----> NOUN ::::: hand
# reach ----> VERB ::::: reach
# for ----> ADP ::::: for
# his ----> PRON ::::: his
# hips ----> NOUN ::::: hip
# as ----> SCONJ ::::: as
# he ----> PRON ::::: he
# studies ----> VERB ::::: study
# an ----> DET ::::: an
# impossible ----> ADJ ::::: impossible
# situation ----> NOUN ::::: situation
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# CUT ----> PROPN ::::: CUT
# TO ----> ADP ::::: to
# JACOB ----> PROPN ::::: JACOB
# stepping ----> VERB ::::: step
# cautiously ----> ADV ::::: cautiously
# onto ----> ADP ::::: onto
# the ----> DET ::::: the
# ladder ----> NOUN ::::: ladder
# going ----> VERB ::::: go
# down ----> ADP ::::: down
# to ----> ADP ::::: to
# the ----> DET ::::: the
#
#  ----> SPACE :::::
#
# tracks ----> NOUN ::::: track
# . ----> PUNCT ::::: .
# A ----> DET ::::: a
# rat ----> NOUN ::::: rat
# scampers ----> NOUN ::::: scamper
# by ----> ADV ::::: by
# and ----> CCONJ ::::: and
# he ----> PRON ::::: he
# gasps ----> VERB ::::: gasp
# . ----> PUNCT ::::: .
#
#
# 				 ----> SPACE :::::
#
#
# JACOB ----> PROPN ::::: JACOB
#
# 		 ----> SPACE :::::
#
# No ----> DET ::::: no
# way ----> NOUN ::::: way
# ! ----> PUNCT ::::: !
#
#
#  ----> SPACE :::::
#
#
# He ----> PRON ::::: he
# starts ----> VERB ::::: start
# to ----> PART ::::: to
# climb ----> VERB ::::: climb
# back ----> ADV ::::: back
# up ----> ADP ::::: up
# the ----> DET ::::: the
# ladder ----> NOUN ::::: ladder
# but ----> CCONJ ::::: but
# sees ----> VERB ::::: see
# that ----> SCONJ ::::: that
# ...
# Ernest ----> PROPN ::::: Ernest
# , ----> PUNCT ::::: ,
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# really ----> ADV ::::: really
# believe ----> VERB ::::: believe
# it ----> PRON ::::: it
# will ----> AUX ::::: will
# work ----> VERB ::::: work
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# know ----> VERB ::::: know
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# mind ----> VERB ::::: mind
# fightin ----> NOUN ::::: fightin
# ' ----> PUNCT ::::: '
# for ----> ADP ::::: for
# an ----> DET ::::: an
# impossible ----> ADJ ::::: impossible
# cause ----> NOUN ::::: cause
# . ----> PUNCT ::::: .
# Anyway ----> ADV ::::: anyway
# it ----> PRON ::::: it
# beats ----> VERB ::::: beat
# just ----> ADV ::::: just
# giving ----> VERB ::::: give
# up ----> ADP ::::: up
# and ----> CCONJ ::::: and
# doing ----> VERB ::::: do
# nothing ----> PRON ::::: nothing
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# starts ----> VERB ::::: start
# walking ----> VERB ::::: walk
# away ----> ADV ::::: away
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Maria ----> PROPN ::::: Maria
# ... ----> PUNCT ::::: ...
# thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#  ----> SPACE :::::
#
#
#
# The ----> DET ::::: the
# following ----> VERB ::::: follow
# dialouge ----> NOUN ::::: dialouge
# takes ----> VERB ::::: take
# place ----> NOUN ::::: place
# if ----> SCONJ ::::: if
# you ----> PRON ::::: you
# try ----> VERB ::::: try
# to ----> PART ::::: to
# go ----> VERB ::::: go
# through ----> ADP ::::: through
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# once ----> ADV ::::: once
# more ----> ADV ::::: more
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# think ----> VERB ::::: think
# miracles ----> NOUN ::::: miracle
# really ----> ADV ::::: really
# can ----> AUX ::::: can
# happen ----> VERB ::::: happen
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# Silent ----> PROPN ::::: Silent
# Hill ----> PROPN ::::: Hill
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# , ----> PUNCT ::::: ,
# maybe ----> ADV ::::: maybe
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# problem ----> NOUN ::::: problem
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# Maria ----> PROPN ::::: Maria
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# think ----> VERB ::::: think
# too ----> ADV ::::: too
# much ----> ADJ ::::: much
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# from ----> ADP ::::: from
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# my ----> PRON ::::: my
# town ----> NOUN ::::: town
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# 3 ----> X ::::: 3
# - ----> PUNCT ::::: -
# Ernest ----> PROPN ::::: Ernest
# 's ----> PART ::::: 's
# Request ----> NOUN ::::: request
#
#  ----> SPACE :::::
#
# 4 ----> NUM ::::: 4
# - ----> PUNCT ::::: -
# The ----> DET ::::: the
# Truth ----> NOUN ::::: truth
# About ----> ADP ::::: about
# Ernest ----> PROPN ::::: Ernest
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# returns ----> NOUN ::::: return
# to ----> ADP ::::: to
# the ----> DET ::::: the
# bedroom ----> NOUN ::::: bedroom
# door ----> NOUN ::::: door
# with ----> ADP ::::: with
# the ----> DET ::::: the
# white ----> ADJ ::::: white
# liquid ----> NOUN ::::: liquid
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Thank ----> VERB ::::: thank
# you ----> PRON ::::: you
# Maria ----> PROPN ::::: Maria
# . ----> PUNCT ::::: .
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# only ----> ADJ ::::: only
# item ----> NOUN ::::: item
# I ----> PRON ::::: I
# could ----> AUX ::::: could
# n't ----> PART ::::: not
# get ----> VERB ::::: get
# myself ----> PRON ::::: myself
# . ----> PUNCT ::::: .
# By ----> ADP ::::: by
# the ----> DET ::::: the
# time ----> NOUN ::::: time
# I ----> PRON ::::: I
# found ----> VERB ::::: find
# out ----> ADP ::::: out
# about ----> ADP ::::: about
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# could ----> AUX ::::: could
# no ----> ADV ::::: no
# longer ----> ADV ::::: long
# leave ----> VERB ::::: leave
# this ----> DET ::::: this
# house ----> NOUN ::::: house
# . ----> PUNCT ::::: .
# So ----> ADV ::::: so
# long ----> ADV ::::: long
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# will ----> AUX ::::: will
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Maria ----> PROPN ::::: Maria
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# Gods ----> PROPN ::::: Gods
# are ----> AUX ::::: be
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# know ----> VERB ::::: know
# it ----> PRON ::::: it
# too ----> ADV ::::: too
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# were ----> AUX ::::: be
# born ----> VERB ::::: bear
# in ----> ADP ::::: in
# this ----> DET ::::: this
# town ----> NOUN ::::: town
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# sure ----> ADJ ::::: sure
# ' ----> PUNCT ::::: '
# God ----> PROPN ::::: God
# ' ----> PUNCT ::::: '
# is ----> AUX ::::: be
# the ----> DET ::::: the
# right ----> ADJ ::::: right
# word ----> NOUN ::::: word
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# believe ----> VERB ::::: believe
# in ----> ADP ::::: in
# Fate ----> PROPN ::::: Fate
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Not ----> PART ::::: not
# really ----> ADV ::::: really
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# fine ----> ADJ ::::: fine
# then ----> ADV ::::: then
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Ernest ----> PROPN ::::: Ernest
# , ----> PUNCT ::::: ,
# can ----> AUX ::::: can
# I ----> PRON ::::: I
# open ----> VERB ::::: open
# this ----> PRON ::::: this
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# dead ----> ADJ ::::: dead
# end ----> NOUN ::::: end
# . ----> PUNCT ::::: .
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# nothing ----> PRON ::::: nothing
# beyond ----> ADP ::::: beyond
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
# So ----> ADV ::::: so
# ... ----> PUNCT ::::: ...
# What ----> PRON ::::: what
# if ----> SCONJ ::::: if
# I ----> PRON ::::: I
# had ----> AUX ::::: have
# said ----> VERB ::::: say
# I ----> PRON ::::: I
# believed ----> VERB ::::: believe
# in ----> ADP ::::: in
# Fate ----> PROPN ::::: Fate
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# That ----> SCONJ ::::: that
# James ----> PROPN ::::: James
# , ----> PUNCT ::::: ,
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# man ----> NOUN ::::: man
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# James ----> PROPN ::::: James
# ... ----> PUNCT ::::: ...
# ? ----> PUNCT ::::: ?
# Y ----> PROPN ::::: Y
# , ----> PUNCT ::::: ,
# yes ----> INTJ ::::: yes
# ...... ----> PUNCT ::::: ......
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# looking ----> VERB ::::: look
# for ----> ADP ::::: for
# the ----> DET ::::: the
# you ----> PRON ::::: you
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Because ----> SCONJ ::::: because
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# kind ----> ADJ ::::: kind
# . ----> PUNCT ::::: .
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
# know ----> VERB ::::: know
# something ----> PRON ::::: something
# ? ----> PUNCT ::::: ?
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# ..... ----> PUNCT ::::: .....
# Maria ----> PROPN ::::: Maria
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Anyway ----> INTJ ::::: anyway
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# just ----> ADV ::::: just
# what ----> PRON ::::: what
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# . ----> PUNCT ::::: .
# You ----> PRON ::::: you
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# really ----> ADV ::::: really
# know ----> VERB ::::: know
# anything ----> PRON ::::: anything
# . ----> PUNCT ::::: .
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# fine ----> ADJ ::::: fine
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Ernest ----> PROPN ::::: Ernest
# : ----> PUNCT ::::: :
# OK ----> INTJ ::::: ok
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# opens ----> VERB ::::: open
# the ----> DET ::::: the
# door ----> NOUN ::::: door
# and ----> CCONJ ::::: and
# enters ----> VERB ::::: enter
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# is ----> AUX ::::: be
# completley ----> ADV ::::: completley
# empty ----> ADJ ::::: empty
# . ----> PUNCT ::::: .
# Amy ----> PROPN ::::: Amy
# 's ----> PART ::::: 's
# present ----> NOUN ::::: present
# is ----> AUX ::::: be
# on ----> ADP ::::: on
# the ----> DET ::::: the
# table ----> NOUN ::::: table
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# been ----> AUX ::::: be
# unwrapped ----> ADJ ::::: unwrapped
# . ----> PUNCT ::::: .
# Maria ----> PROPN ::::: Maria
# looks ----> VERB ::::: look
# around ----> ADP ::::: around
# the ----> DET ::::: the
# room ----> NOUN ::::: room
# for ----> ADP ::::: for
# a ----> DET ::::: a
# while ----> NOUN ::::: while
# and ----> CCONJ ::::: and
# then ----> ADV ::::: then
# leaves ----> VERB ::::: leave
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# 4 ----> NUM ::::: 4
# - ----> PUNCT ::::: -
# The ----> DET ::::: the
# Truth ----> NOUN ::::: truth
# About ----> ADP ::::: about
# Ernest ----> PROPN ::::: Ernest
#
#  ----> SPACE :::::
#
# 5 ----> NUM ::::: 5
# - ----> PUNCT ::::: -
# Maria ----> PROPN ::::: Maria
# Meets ----> PROPN ::::: Meets
# James ----> PROPN ::::: James
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# is ----> AUX ::::: be
# walking ----> VERB ::::: walk
# down ----> ADP ::::: down
# a ----> DET ::::: a
# narrow ----> ADJ ::::: narrow
# road ----> NOUN ::::: road
# . ----> PUNCT ::::: .
# She ----> PRON ::::: she
# stops ----> VERB ::::: stop
# and ----> CCONJ ::::: and
# holds ----> VERB ::::: hold
# her ----> PRON ::::: her
# gun ----> NOUN ::::: gun
# to ----> ADP ::::: to
# her ----> PRON ::::: her
# head ----> NOUN ::::: head
# . ----> PUNCT ::::: .
# After ----> ADP ::::: after
# a ----> DET ::::: a
# while ----> NOUN ::::: while
# she ----> PRON ::::: she
# throws ----> VERB ::::: throw
# the ----> DET ::::: the
# gun ----> NOUN ::::: gun
# over ----> ADP ::::: over
# a ----> DET ::::: a
# wall ----> NOUN ::::: wall
# and ----> CCONJ ::::: and
# continues ----> VERB ::::: continue
# walking ----> VERB ::::: walk
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# James ----> PROPN ::::: James
# ...... ----> PUNCT ::::: ......
#
#
#  ----> SPACE :::::
#
#
# The ----> DET ::::: the
# screen ----> NOUN ::::: screen
# goes ----> VERB ::::: go
# black ----> ADJ ::::: black
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# James ----> PROPN ::::: James
# : ----> PUNCT ::::: :
# Mary ----> PROPN ::::: Mary
# ? ----> PUNCT ::::: ?
# No ----> INTJ ::::: no
# ... ----> PUNCT ::::: ...
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# . ----> PUNCT ::::: .
#
#  ----> SPACE :::::
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# I ----> PRON ::::: I
# look ----> VERB ::::: look
# like ----> ADP ::::: like
# your ----> PRON ::::: your
# girlfriend ----> NOUN ::::: girlfriend
# ? ----> PUNCT ::::: ?
# My ----> PRON ::::: my
# name ----> NOUN ::::: name
# ... ----> PUNCT ::::: ...
# is ----> AUX ::::: be
# Maria ----> PROPN ::::: Maria
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# 5 ----> NUM ::::: 5
# - ----> PUNCT ::::: -
# Maria ----> PROPN ::::: Maria
# Meets ----> PROPN ::::: Meets
# James ----> PROPN ::::: James
#
#  ----> SPACE :::::
#
# 6 ----> NUM ::::: 6
# - ----> PUNCT ::::: -
# Misc ----> PROPN ::::: Misc
#
#  ----> SPACE :::::
#
# If ----> SCONJ ::::: if
# you ----> PRON ::::: you
# try ----> VERB ::::: try
# to ----> PART ::::: to
# enter ----> VERB ::::: enter
# Brookhaven ----> PROPN ::::: Brookhaven
# Hospital ----> PROPN ::::: Hospital
# : ----> PUNCT ::::: :
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# nothing ----> PRON ::::: nothing
# for ----> SCONJ ::::: for
# me ----> PRON ::::: I
# to ----> PART ::::: to
# do ----> VERB ::::: do
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# If ----> SCONJ ::::: if
# you ----> PRON ::::: you
# try ----> VERB ::::: try
# to ----> PART ::::: to
# leave ----> VERB ::::: leave
# the ----> DET ::::: the
# Blue ----> PROPN ::::: Blue
# Creek ----> PROPN ::::: Creek
# Apartments ----> PROPN ::::: Apartments
# through ----> ADP ::::: through
# another ----> DET ::::: another
# exit ----> NOUN ::::: exit
# ( ----> PUNCT ::::: (
# where ----> SCONJ ::::: where
# James ----> PROPN ::::: James
# fights ----> VERB ::::: fight
# with ----> ADP ::::: with
# Pyramid ----> PROPN ::::: Pyramid
# Head ----> PROPN ::::: Head
# for ----> ADP ::::: for
# the ----> DET ::::: the
# first ----> ADJ ::::: first
# time ----> NOUN ::::: time
# ): ----> PUNCT ::::: ):
#
#
#  ----> SPACE :::::
#
#
# Maria ----> PROPN ::::: Maria
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# should ----> AUX ::::: should
# take ----> VERB ::::: take
# me ----> PRON ::::: I
# to ----> ADP ::::: to
# the ----> DET ::::: the
# alley ----> NOUN ::::: alley
# that ----> PRON ::::: that
# runs ----> VERB ::::: run
# to ----> ADP ::::: to
# the ----> DET ::::: the
# park ----> NOUN ::::: park
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# first ----> ADV ::::: first
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# better ----> ADV ::::: well
# take ----> VERB ::::: take
# care ----> NOUN ::::: care
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# promise ----> NOUN ::::: promise
# to ----> ADP ::::: to
# Ernest ----> PROPN ::::: Ernest
# . ----> PUNCT ::::: .
#
#
#  ----> SPACE :::::
#
#
# 6 ----> NUM ::::: 6
# - ----> PUNCT ::::: -
# Misc ----> PROPN ::::: Misc
#
#  ----> SPACE :::::
#
# by ----> ADP ::::: by
# Niai ----> PROPN ::::: Niai
# Mitch ----> PROPN ::::: Mitch
# ( ----> PUNCT ::::: (
# Born ----> VERB ::::: bear
# From ----> ADP ::::: from
# A ----> DET ::::: a
# Wish ----> PROPN ::::: Wish
# Game ----> PROPN ::::: Game
# Script ----> PROPN ::::: Script
# ) ----> PUNCT ::::: )
#
#  ----> SPACE :::::
#
# Home ----> NOUN ::::: home
#
#  ----> SPACE :::::
#
# About ----> ADP ::::: about
#
#  ----> SPACE :::::
#
# Links ----> PROPN ::::: Links
#
#  ----> SPACE :::::
#
# Contact ----> NOUN ::::: contact
#
#  ----> SPACE :::::

# %% [markdown]
# Selecting some data

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('mobile', 'jacobs-ladder-script'), ('difficult', 'jacobs-ladder-script'), ('unpaved', 'jacobs-ladder-script'), ('interested', 'jacobs-ladder-script'), ('garish', 'jacobs-ladder-script'), ('other', 'jacobs-ladder-script'), ('down', 'jacobs-ladder-script'), ('unrelieved', 'jacobs-ladder-script'), ('psychiatric', 'jacobs-ladder-script'), ('subtle', 'jacobs-ladder-script'), ('spiritual', 'jacobs-ladder-script'), ('distant', 'jacobs-ladder-script'), ('brighten', 'jacobs-ladder-script'), ('heavyset', 'jacobs-ladder-script'), ('stunning', 'jacobs-ladder-script'), ('safe', 'jacobs-ladder-script'), ('audible', 'jacobs-ladder-script'), ('shadowy', 'jacobs-ladder-script'), ('inevitable', 'jacobs-ladder-script'), ('vietnamese', 'jacobs-ladder-script'), ('stepping', 'jacobs-ladder-script'), ('ethereal', 'jacobs-ladder-script'), ('tiny', 'jacobs-ladder-script'), ('effective', 'jacobs-ladder-script'), ('electrical', 'jacobs-ladder-script'), ('naked', 'jacobs-ladder-script'), ('strange', 'jacobs-ladder-script'), ('unbelievable', 'jacobs-ladder-script'), ('glorious', 'jacobs-ladder-script'), ('big', 'jacobs-ladder-script'), ('starry', 'jacobs-ladder-script'), ('aware', 'jacobs-ladder-script'), ('charred', 'jacobs-ladder-script'), ('smokey', 'jacobs-ladder-script'), ('punish-', 'jacobs-ladder-script'), ('special', 'jacobs-ladder-script'), ('strong', 'jacobs-ladder-script'), ('surprising', 'jacobs-ladder-script'), ('spiked', 'jacobs-ladder-script'), ('golden', 'jacobs-ladder-script'), ('impossible', 'jacobs-ladder-script'), ('weird', 'jacobs-ladder-script'), ('transcendental', 'jacobs-ladder-script'), ('chemical', 'jacobs-ladder-script'), ('surgical', 'jacobs-ladder-script'), ('french', 'jacobs-ladder-script'), ('soporific', 'jacobs-ladder-script'), ('eerie', 'jacobs-ladder-script'), ('unearthly', 'jacobs-ladder-script'), ('whole', 'jacobs-ladder-script'), ('pathetic', 'jacobs-ladder-script'), ('front', 'jacobs-ladder-script'), ('least', 'jacobs-ladder-script'), ('burst-', 'jacobs-ladder-script'), ('significant', 'jacobs-ladder-script'), ('early', 'jacobs-ladder-script'), ('smooth', 'jacobs-ladder-script'), ('hippie', 'jacobs-ladder-script'), ('horny', 'jacobs-ladder-script'), ('frightening', 'jacobs-ladder-script'), ('physical', 'jacobs-ladder-script'), ('playful', 'jacobs-ladder-script'), ('messed', 'jacobs-ladder-script'), ('main', 'jacobs-ladder-script'), ('ready', 'jacobs-ladder-script'), ('possible', 'jacobs-ladder-script'), ('reception', 'jacobs-ladder-script'), ('sdiren', 'jacobs-ladder-script'), ('wide', 'jacobs-ladder-script'), ('colored', 'jacobs-ladder-script'), ('violent', 'jacobs-ladder-script'), ('minf', 'jacobs-ladder-script'), ('unconvincing', 'jacobs-ladder-script'), ('romantic', 'jacobs-ladder-script'), ('apt', 'jacobs-ladder-script'), ('fundamental', 'jacobs-ladder-script'), ('wrong', 'jacobs-ladder-script'), ('slipped', 'jacobs-ladder-script'), ('convenient', 'jacobs-ladder-script'), ('fantastic', 'jacobs-ladder-script'), ('pure', 'jacobs-ladder-script'), ('huge', 'jacobs-ladder-script'), ('fresh', 'jacobs-ladder-script'), ('literary', 'jacobs-ladder-script'), ('like', 'jacobs-ladder-script'), ('tawdry', 'jacobs-ladder-script'), ('excruciating', 'jacobs-ladder-script'), ('fake', 'jacobs-ladder-script'), ('regular', 'jacobs-ladder-script'), ('catacylsmic', 'jacobs-ladder-script'), ('unable', 'jacobs-ladder-script'), ('drugged', 'jacobs-ladder-script'), ('primordial', 'jacobs-ladder-script'), ('undefinable', 'jacobs-ladder-script'), ('short', 'jacobs-ladder-script'), ('liquid', 'jacobs-ladder-script'), ('little', 'jacobs-ladder-script'), ('quick', 'jacobs-ladder-script'), ('superhuman', 'jacobs-ladder-script'), ('alive', 'jacobs-ladder-script'), ('sorry', 'jacobs-ladder-script'), ('entire', 'jacobs-ladder-script'), ('rainy', 'jacobs-ladder-script'), ('marked', 'jacobs-ladder-script'), ('lazy', 'jacobs-ladder-script'), ('heavy', 'jacobs-ladder-script'), ('disturbed', 'jacobs-ladder-script'), ('terrifying', 'jacobs-ladder-scri ...
# {('horrible', 'shinning-dialogue'), ('nice', 'shinning-dialogue'), ('red', 'shinning-dialogue'), ('only', 'shinning-dialogue'), ('ethical', 'shinning-dialogue'), ('feasible', 'shinning-dialogue'), ('melodramatic', 'shinning-dialogue'), ('comfortable', 'shinning-dialogue'), ('light', 'shinning-dialogue'), ('particular', 'shinning-dialogue'), ('regular', 'shinning-dialogue'), ('long', 'shinning-dialogue'), ('emotional', 'shinning-dialogue'), ('swell', 'shinning-dialogue'), ('naughty', 'shinning-dialogue'), ('dizzy', 'shinning-dialogue'), ('less', 'shinning-dialogue'), ('little', 'shinning-dialogue'), ('quick', 'shinning-dialogue'), ('asleep', 'shinning-dialogue'), ('outstretched', 'shinning-dialogue'), ('front', 'shinning-dialogue'), ('oven', 'shinning-dialogue'), ('silly', 'shinning-dialogue'), ('beautiful', 'shinning-dialogue'), ('advisory', 'shinning-dialogue'), ('entire', 'shinning-dialogue'), ('run', 'shinning-dialogue'), ('corridor', 'shinning-dialogue'), ('early', 'shinning-dialogue'), ('upper', 'shinning-dialogue'), ('own', 'shinning-dialogue'), ('tremendous', 'shinning-dialogue'), ('fascinated', 'shinning-dialogue'), ('easy', 'shinning-dialogue'), ('ready', 'shinning-dialogue'), ('grouchy', 'shinning-dialogue'), ('marvellous', 'shinning-dialogue'), ('unreliable', 'shinning-dialogue'), ('single', 'shinning-dialogue'), ('crowded', 'shinning-dialogue'), ('local', 'shinning-dialogue'), ('ridiculous', 'shinning-dialogue'), ('about', 'shinning-dialogue'), ('empty', 'shinning-dialogue'), ('clean', 'shinning-dialogue'), ('sure', 'shinning-dialogue'), ('new', 'shinning-dialogue'), ('enormous', 'shinning-dialogue'), ('busy', 'shinning-dialogue'), ('goddam', 'shinning-dialogue'), ('half', 'shinning-dialogue'), ('uncommon', 'shinning-dialogue'), ('scared', 'shinning-dialogue'), ('important', 'shinning-dialogue'), ('dull', 'shinning-dialogue'), ('momentary', 'shinning-dialogue'), ('typical', 'shinning-dialogue'), ('bare', 'shinning-dialogue'), ('many', 'shinning-dialogue'), ('afraid', 'shinning-dialogue'), ('soiree', 'shinning-dialogue'), ('first', 'shinning-dialogue'), ('awful', 'shinning-dialogue'), ('definite', 'shinning-dialogue'), ('alive', 'shinning-dialogue'), ('willful', 'shinning-dialogue'), ('bottom', 'shinning-dialogue'), ('heated', 'shinning-dialogue'), ('close', 'shinning-dialogue'), ('portable', 'shinning-dialogue'), ('sorry', 'shinning-dialogue'), ('advocaat', 'shinning-dialogue'), ('pink', 'shinning-dialogue'), ('elderly', 'shinning-dialogue'), ('closed', 'shinning-dialogue'), ('round', 'shinning-dialogue'), ('hot', 'shinning-dialogue'), ('urgent', 'shinning-dialogue'), ('famous', 'shinning-dialogue'), ('Most', 'shinning-dialogue'), ('heavy', 'shinning-dialogue'), ('bright', 'shinning-dialogue'), ('different', 'shinning-dialogue'), ('hard', 'shinning-dialogue'), ('much', 'shinning-dialogue'), ('pleased', 'shinning-dialogue'), ('concerned', 'shinning-dialogue'), ('shuttered', 'shinning-dialogue'), ('yellow', 'shinning-dialogue'), ('revealing', 'shinning-dialogue'), ('dead', 'shinning-dialogue'), ('high', 'shinning-dialogue'), ('national', 'shinning-dialogue'), ('same', 'shinning-dialogue'), ('inner', 'shinning-dialogue'), ('fine', 'shinning-dialogue'), ('small', 'shinning-dialogue'), ('complete', 'shinning-dialogue'), ('claustrophobic', 'shinning-dialogue'), ('l.ear', 'shinning-dialogue'), ('crazy', 'shinning-dialogue'), ('staggering', 'shinning-dialogue'), ('gorgeous', 'shinning-dialogue'), ('open', 'shinning-dialogue'), ('fucking', 'shinning-dialogue'), ('hon', 'shinning-dialogue'), ('incredible', 'shinning-dialogue'), ('few', 'shinning-dialogue'), ('indian', 'shinning-dialogue'), ('imaginary', 'shinning-dialogue'), ('tired', 'shinning-dialogue'), ('general', 'shinning-dialogue'), ('mid', 'shinning-dialogue'), ('true', 'shinning-dialogue'), ('next', 'shinning-dialogue'), ('cruel', 'shinning-dialogue'), ('d', 'shinning-dialogue'), ('well', 'shinning-dialogue'), ('confused', 'shinning-dialogue'), ('right', 'shinning-d ...
# {('3rd', 'game-dialogue'), ('sad', 'game-dialogue'), ('next', 'game-dialogue'), ('afraid', 'game-dialogue'), ('deaf', 'game-dialogue'), ('scrambled', 'game-dialogue'), ('right', 'game-dialogue'), ('huh', 'game-dialogue'), ('great', 'game-dialogue'), ('magic', 'game-dialogue'), ('worth', 'game-dialogue'), ('strange', 'game-dialogue'), ('different', 'game-dialogue'), ('deserted', 'game-dialogue'), ('last', 'game-dialogue'), ('glad', 'game-dialogue'), ('narrow', 'game-dialogue'), ('haunted', 'game-dialogue'), ('dead', 'game-dialogue'), ('left', 'game-dialogue'), ('nlp', 'game-dialogue'), ('real', 'game-dialogue'), ('sweet', 'game-dialogue'), ('lost', 'game-dialogue'), ('unreachable', 'game-dialogue'), ('able', 'game-dialogue'), ('fine', 'game-dialogue'), ('second', 'game-dialogue'), ('stupid', 'game-dialogue'), ('honest', 'game-dialogue'), ('wooden', 'game-dialogue'), ('fast', 'game-dialogue'), ('comfy', 'game-dialogue'), ('gutless', 'game-dialogue'), ('other', 'game-dialogue'), ('more', 'game-dialogue'), ('green', 'game-dialogue'), ('okay', 'game-dialogue'), ('torn', 'game-dialogue'), ('quiet', 'game-dialogue'), ('bad', 'game-dialogue'), ('dark', 'game-dialogue'), ('few', 'game-dialogue'), ('motionless', 'game-dialogue'), ('good', 'game-dialogue'), ('true', 'game-dialogue'), ('safe', 'game-dialogue'), ('well', 'game-dialogue'), ('computerized', 'game-dialogue'), ('careful', 'game-dialogue'), ('confused', 'game-dialogue'), ('weak', 'game-dialogue'), ('pretty', 'game-dialogue'), ('key', 'game-dialogue'), ('ugly', 'game-dialogue'), ('disgusting', 'game-dialogue'), ('clear', 'game-dialogue'), ('sudden', 'game-dialogue'), ('effective', 'game-dialogue'), ('several', 'game-dialogue'), ('satisfied', 'game-dialogue'), ('big', 'game-dialogue'), ('nuts', 'game-dialogue'), ('lookin', 'game-dialogue'), ('large', 'game-dialogue'), ('third', 'game-dialogue'), ('final', 'game-dialogue'), ('fun', 'game-dialogue'), ('optional', 'game-dialogue'), ('terrible', 'game-dialogue'), ('alternate', 'game-dialogue'), ('special', 'game-dialogue'), ('opposite', 'game-dialogue'), ('dirty', 'game-dialogue'), ('middle', 'game-dialogue'), ('various', 'game-dialogue'), ('sacred', 'game-dialogue'), ('gritty', 'game-dialogue'), ('weird', 'game-dialogue'), ('lucky', 'game-dialogue'), ('impossible', 'game-dialogue'), ('nice', 'game-dialogue'), ('vile', 'game-dialogue'), ('late', 'game-dialogue'), ('only', 'game-dialogue'), ('bloody', 'game-dialogue'), ('happy', 'game-dialogue'), ('grainy', 'game-dialogue'), ('old', 'game-dialogue'), ('mad', 'game-dialogue'), ('sick', 'game-dialogue'), ('jokin', 'game-dialogue'), ('long', 'game-dialogue'), ('peaceful', 'game-dialogue'), ('whole', 'game-dialogue'), ('funny', 'game-dialogue'), ('short', 'game-dialogue'), ('double', 'game-dialogue'), ('less', 'game-dialogue'), ('kind', 'game-dialogue'), ('front', 'game-dialogue'), ('dangerous', 'game-dialogue'), ('silly', 'game-dialogue'), ('random', 'game-dialogue'), ('beautiful', 'game-dialogue'), ('underwater', 'game-dialogue'), ('dumb', 'game-dialogue'), ('adjacent', 'game-dialogue'), ('silent', 'game-dialogue'), ('tedious', 'game-dialogue'), ('nervous', 'game-dialogue'), ('damn', 'game-dialogue'), ('dear', 'game-dialogue'), ('full', 'game-dialogue'), ('cute', 'game-dialogue'), ('gruesome', 'game-dialogue'), ('own', 'game-dialogue'), ('shaky', 'game-dialogue'), ('necessary', 'game-dialogue'), ('easy', 'game-dialogue'), ('ready', 'game-dialogue'), ('ridiculous', 'game-dialogue'), ('central', 'game-dialogue'), ('innocent', 'game-dialogue'), ('’s', 'game-dialogue'), ('sure', 'game-dialogue'), ('holy', 'game-dialogue'), ('n’t', 'game-dialogue'), ('thrilling', 'game-dialogue'), ('insane', 'game-dialogue'), ('black', 'game-dialogue'), ('surly', 'game-dialogue'), ('white', 'game-dialogue'), ('wrong', 'game-dialogue'), ('ill', 'game-dialogue'), ('red', 'game-dialogue'), ('warm', 'game-dialogue'), ('8th', 'game-dialogue'), ('fiery', 'game-dialogue'), ('human', 'game-dialogue'), ('alone', 'gam ...

# %% [markdown]
# TSV file

# %%
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
   
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
           
            allDataFrames.append(myDataFrame)

outputFilePath = 'networkData-2.tsv'

fullDataFrame = pd.concat(allDataFrames, ignore_index=True)


fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Out:
# I just saved a NEW dataframe as a NEW TSV file.
