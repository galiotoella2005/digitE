# %% [markdown]
# # Jupyter Notebook Homework

# %%
import nltk
import nltk.corpus
nltk.download('book')
from nltk.book import *
from urllib import request
import matplotlib
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/ellagalioto/nltk_data...
# ...

# %%
import nltk
import nltk.corpus

localFile = open("jacobs-ladder-script.txt", 'r', encoding='utf-8')
jacob = localFile.read()
localFile.close()

jacobTokens = jacob.split()

lowerCaseTokens = [w.lower() for w in jacobTokens]
print(f"lowerCaseTokens = {lowerCaseTokens}")
# Out:
# lowerCaseTokens = ['"jacob\'s', 'ladder"', 'by', 'bruce', 'joel', 'rubin', 'ext.', 'vietnam', '-', 'dusk', 'a', 'swarm', 'of', 'helicopters', 'swoops', 'out', 'of', 'a', 'yellow', 'sky', 'and', 'deposits', 'an', 'army', 'of', 'men', 'over', 'a', 'vietnamese', 'hillside.', 'the', 'soldiers', 'scramble', 'over', 'the', 'terraced', 'rice', 'paddies', 'for', 'the', 'protection', 'of', 'the', 'jungle.', 'falling', 'into', 'coulmns,', 'like', 'strands', 'of', 'soldier', 'ants,', 'seventy-five', 'men,', 'at', 'combat', 'readiness,', 'assemble', 'on', 'the', 'edge', 'of', 'a', 'sweltering', 'wilderness.', 'it', 'is', 'dusk.', 'the', 'mood', 'is', 'lazy,', 'soporific.', 'members', 'of', 'one', 'platoon', 'huddle', 'close', 'to', 'the', 'ground', 'smoking', 'a', 'joint.', 'jerry', 'strong', 'stuff.', 'rod', '(to', 'jacob,', 'a', 'soldier', 'squatting', 'several', 'yards', 'away)', 'hey,', 'professor,', 'how', 'many', 'times', 'can', 'you', 'shit', 'in', 'an', 'hour?', 'george', "don't", 'bug',
# ...

# %%
import nltk
import matplotlib.pyplot as plt
import re

with open("jacobs-ladder-script.txt", 'r', encoding='utf-8') as f:
    jacob = f.read()

words = ["dream", "death", "memory", "pain"]

nltk.draw.dispersion_plot(jacobText, words)
plt.show()
